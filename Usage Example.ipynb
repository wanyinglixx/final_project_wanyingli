# %%
#install the package
pip install final_project_wanyingli
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.1; however, version 20.3.3 is available.
# You should consider upgrading via the 'c:\users\wanyi\appdata\local\pypoetry\cache\virtualenvs\mds-u7jpnxli-py3.8\scripts\python.exe -m pip install --upgrade pip' command.

# %%
#import the package
from final_project_wanyingli import final_project_wanyingli as wl

# %% [markdown]
# ## Part 1 - World Bank API Client

# %%
# use this function to fetch all country lending project information from the WB.
wl.get_wb_lending()
# Out:
#               id                                       project_name  \
# P172972  P172972  Additional Financing for the Multipurpose Cada...
# P174813  P174813  Third Additional Financing for the Sierra Leon...
# P166672  P166672  ID: Jambi Sustainable Landscape Management Pro...
# P170914  P170914  Promoting Competitiveness and Enhancing Resili...
# P171751  P171751  Uzbekistan: Supporting a Transparent and Inclu...
# ...          ...                                                ...
# P162671  P162671       Rwanda Energy Sector Development Policy Loan
# P157702  P157702    Tamil Nadu Rural Transformation Project (TNRTP)
# P158092  P158092  Rwanda Feeder Roads Development Project - Addi...
# P158522  P158522  Tamil Nadu Irrigated Agriculture Modernization...
# P162402  P162402    Economic Management Support Operation First DPF
#
#             boardapprovaldate   totalamt countrycode  \
# P172972  2020-12-17T00:00:00Z          0          CO
# ...

# %%
# use this function to fetch all projects received by a given country in a time period. This example shows the results of Nepal from 2018-2020.
wl.get_wb_countryyear('NP', 2018,2020)
# Out:
# The total lending amount received by NP from 2018 to 2020 is: $2078.0 million
#               id                                       project_name  \
# P170215  P170215  Rural Enterprise and Economic Development Project
# P163418  P163418  Nepal Urban Governance and Infrastructure Project
# P173044  P173044    Finance for Growth Development Policy Financing
# P174209  P174209              CoVID 19 School Sector Response (GPE)
# P170798  P170798                     Forests for Prosperity Project
# P170409  P170409  Nepal Strategic Road Connectivity and Trade Im...
# P170248  P170248  Second Programmatic Energy Sector Development ...
# P173760  P173760  Nepal: COVID-19 Emergency Response and Health ...
# P166788  P166788    Nepal Development Policy Financing with CAT DDO
# P170565  P170565  Second Additional Financing Earthquake Housing...
# P160696  P160696  Youth Employment Transformation Initiative Pro...
# P167047  P167047  Nepal: Additional Financing for School Sector ...
# ...

# %%
# use this function to fetch project information with a specific environmenal category during a time period.
wl.get_wb_environment('B', 2018, 2019)
# Out:
# The total lending amount of projects with environmental category of B from 2018 to 2019 is: $8895.310000000001 million
#               id                                       project_name  \
# P168310  P168310  State of Maharashtra's Agribusiness and Rural ...
# P162938  P162938                  South Tarawa Water Supply Project
# P165945  P165945                Livestock Commercialization Project
# P162679  P162679  West Bengal Major Irrigation and Flood Managem...
# P160277  P160277           Chile REDD+ Emissions Reductions Program
# ...          ...                                                ...
# P162043  P162043   Western Balkans Trade and Transport Facilitation
# P164941  P164941               Tonga: Pathway to Sustainable Oceans
# P169125  P169125      El Salvador Local Economic Resilience Project
# P162675  P162675                         Cambodia Nutrition Project
# P166730  P166730  Guyana Petroleum Resources Governance and Mana...
#
# ...

# %% [markdown]
# ## Part 2: ADB dataset functions

# %%
#use this function to fetch all sovereign lending projects from the ADB since 2008.
wl.get_adb_lending()
# Out:
#                                            Project Name ADB Financing (US$)  \
# 0                         Melamchi Water Supply Project        145000000.00
# 1     Community-Managed Irrigated Agriculture Sector...         50000000.00
# 2     Kathmandu Valley Water Supply Improvement Project        170000000.00
# 3     Southwest Area Integrated Water Resources Plan...         45000000.00
# 4     Third Small Towns Water Supply and Sanitation ...         60000000.00
# ...                                                 ...                 ...
# 3984  Enhancing Knowledge and Capacity for Project M...           225000.00
# 3985  Preparing the Funafuti Water and Sanitation Pr...          4000000.00
# 3986  State-Owned Enterprises Reform Program, Subpro...        100000000.00
# 3987  Fiscal and Debt Sustainability Program (Subpro...        180000000.00
# 3988  Improving Market Linkages for Cottage and Smal...                   0
#
# ...

# %%
#use this function to fetch all lending projects received by a specific country in a given year. This example shows results of projects in Nepal in 2019.
wl.get_adb_countryyear('NP', 2019)
# Out:
# The total lending amount received by NP is: $274936.79 million
#                                            Project Name ADB Financing (US$)  \
# 24    Preparing the South Asia Subregional Economic ...          1000000.00
# 537   Food Safety and Agriculture Commercialization ...         50500000.00
# 992   South Asia Subregional Economic Cooperation Mu...        195500000.00
# 1100                 Rural Enterprise Financing Project         50750000.00
# 1116  Portfolio Management and Capacity Development ...          1500000.00
#
#      Country countrycode Approval Date  ($) millions  Approval Year
# 24     Nepal          NP    2019-11-27          1.00         2019.0
# 537    Nepal          NP    2019-10-31         50.50         2019.0
# 992    Nepal          NP    2019-10-29        195.50         2019.0
# 1100   Nepal          NP    2019-11-11         50.75         2019.0
# 1116   Nepal          NP    2019-09-18          1.50         2019.0

# %%
#use this function to plot the top 10 receipient countries from the ADB since 2008. Please note that all values are in $millions.
wl.plot_adb_top10()
